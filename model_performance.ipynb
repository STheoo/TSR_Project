# %% [markdown]
# ## Training loss plots
#
# Looking at the loss plot we are trying to judge if the amount of epochs done for training were sufficient or to identify over training. Looking at the plots it seems like all plots level out on the last epoch and it is sufficient as there is also minimal loss. Few more epochs could be considered.

# %%
from IPython.display import display, Image

display(Image(filename='./yolov9/runs/train/exp/results.png'))

# %% [markdown]
# ## Confusion Matrix
#
# Here we can evaluate the performance of each class and their predicted percentage. On the diagonal we want all to be very dark blue. The darker the square the bigger the percentage of signs were predicted correct on the diagonal. Therefore looking at the matrix we can tell 80km Speed Limit, 100km Speed limit were predicted wrong quite a few times. Also there is an interesting pattern were keep right/keep left and go straight or left/go straight or right signs are lighter and boxes around it have light coloring which shows us that they are being confused with each other.

# %%
display(Image(filename='./yolov9/runs/train/exp/confusion_matrix.png'))

# %% [markdown]
# ## R Curve Plot
# With this plot we can see how many false positives there are within different confidence thresholds. Ideally as a traffic sign recognition machine we wouldn't want any false positives as those are traffic signs missed and recall is only 1 at 0 confidence. But, as for the project which is for educational purposes we can use a threshold of 0.8 to confidently detect over 90% of the traffic signs.

# %%
display(Image(filename='./yolov9/runs/train/exp/r_curve.png'))
